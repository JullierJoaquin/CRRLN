# %%
# Paso 1: Importar librerías necesarias
import pandas as pd

# Paso 2: Cargar el archivo CSV
file_path = "data\Base_de_Datos_de_Costos.csv"  # Cambiar si el archivo tiene otro nombre o ruta
df = pd.read_csv(file_path, skiprows=11)

# Paso 3: Limpiar el DataFrame
#df = df.drop(columns=["Unnamed: 0"])  # Eliminar columna vacía
#df.columns = [
#    "Codigo", "Descripcion", "Unidad", 
#    "Costo_Materiales", "Costo_Ejecucion", "Costo_Total"
#]
#df = df[df["Descripcion"].notna()]  # Eliminar filas vacías

# Paso 4: Mostrar las primeras filas
#df.head()

df
# Out:
#       10   1.08       Demolición estructuras de hormigón armado   m3  \
# 0     11   1.09       Demolición mamposterías ladrillos comunes   m3
# 1     12   1.10        Demolición mamposterías ladrillos huecos   m2
# 2     13   1.11                             Picado de revoques    m2
# 3     14   1.12                  Retiro de pisos/revestimientos   m2
# 4     15   2.00                            MOVIMIENTO DE TIERRA  NaN
# ..   ...    ...                                             ...  ...
# 263  275  20.00                                          VARIOS  NaN
# 264  276  20.01                                Ayuda de gremio    m2
# 265  277  20.02  Conductos ventilación, incl. sombrerete y reja    m
# 266  278  20.03      Limpieza periódica y final de obra de obra   m2
# 267  279  20.04                           Parquización (cesped)   m2
#
#           $ 0,00 $ 206.300,29 $ 206.300,29.1
# 0         $ 0,00  $ 87.072,76    $ 87.072,76
# 1         $ 0,00  $ 15.012,24    $ 15.012,24
# ...
